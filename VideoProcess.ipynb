# %% [markdown]
# # Video Processing
# ## First save video to images

# %%
import os
cwd = os.getcwd()
os.path.split(cwd)
# Out:
# ('C:\\Users\\Patrick\\OneDrive\\Code', 'dcscn-super-resolution')

# %%
import cv2
import numpy as np
import multiprocessing as mp
import os
import subprocess as sp
import sys

def video_to_images():
    """
        test everything
    """    
    # We use a K80 GPU with 24GB memory, which can fit 3 images.
    #batch_size = 1
    # Define directory and file names
    save_dir = "../data/videos/images_angel_jpg"
    video_dir = "../data/videos"
    video_file = "../data/videos/angel_eyes3_big.wmv"
    
    #Define absolute directory paths
    ROOT_DIR = os.getcwd()
    VIDEO_DIR = os.path.join(video_dir)
    VIDEO_SAVE_DIR = os.path.join(save_dir)
    VIDEO_FILE_PATH = os.path.join(video_file)
    
    capture = cv2.VideoCapture(VIDEO_FILE_PATH)
    #capture.set(cv2.CAP_PROP_POS_FRAMES, frame_jump * group_number)
    try:
        if not os.path.exists(VIDEO_SAVE_DIR):
            os.makedirs(VIDEO_SAVE_DIR)
    except OSError:
        print ('Error: Creating directory of data')
    
    #num_processes = mp.cpu_count()
    #num_frames = cv2.VideoCapture(VIDEO_FILE_PATH).get(cv2.CAP_PROP_FRAME_COUNT)
    #frame_jump =  num_frames // num_processes
    frames = []
    frame_count = 0

    while True:
        ret, frame = capture.read()
        # Bail out when the video file ends
        if not ret:
            break
        frame_count += 1
        # Save each frame of the video to a list
#         print('group: {0:0}, frame: {0:0>6}'.format(group_number, frame_count))
        print('frame: {0:0>6}'.format(frame_count))
        #frames.append(frame)
#         name = '{0:0}_{0:0>6}.jpg'.format(group_number, frame_count)# + i - batch_size)
        name = '{0:0>6}.jpg'.format(frame_count)# + i - batch_size)
        name = os.path.join(VIDEO_SAVE_DIR, name)
        
        cv2.imwrite(name, frame)
        print('writing to file: {}'.format(name))
        
    capture.release()
    return None
    
# if "__name__"=="__main__":
# Define directory and file names
# save_dir = "images_8minanal"
# video_dir = "videos"
# video_file = "8minanal.mp4"

# # Define absolute directory paths
# ROOT_DIR = os.getcwd()
# VIDEO_DIR = os.path.join(ROOT_DIR, video_dir)
# VIDEO_SAVE_DIR = os.path.join(VIDEO_DIR, save_dir)
# VIDEO_FILE_PATH = os.path.join(VIDEO_DIR, video_file)

# # Set up multiprocessing
# num_processes = mp.cpu_count()
# num_frames = cv2.VideoCapture(VIDEO_FILE_PATH).get(cv2.CAP_PROP_FRAME_COUNT)
# frame_jump =  num_frames // num_processes
# frame_width = cv2.VideoCapture(VIDEO_FILE_PATH).get(cv2.CAP_PROP_FRAME_WIDTH)
# frame_height = cv2.VideoCapture(VIDEO_FILE_PATH).get(cv2.CAP_PROP_FRAME_HEIGHT)
# print("cpus: {}, frames: {}, frame jump: {}, width: {}, height: {}".format(num_processes, num_frames, frame_jump,frame_width, frame_height))

# p = mp.Pool(num_processes)
# p.map(video_to_images, range(num_processes))
video_to_images()
#video_to_images(video_file=video_file, video_dir=video_dir, save_dir=save_dir)
# Out:
# frame: 000001
# writing to file: ../data/videos/images_angel_jpg\000001.jpg
# frame: 000002
# writing to file: ../data/videos/images_angel_jpg\000002.jpg
# frame: 000003
# writing to file: ../data/videos/images_angel_jpg\000003.jpg
# frame: 000004
# writing to file: ../data/videos/images_angel_jpg\000004.jpg
# frame: 000005
# writing to file: ../data/videos/images_angel_jpg\000005.jpg
# frame: 000006
# writing to file: ../data/videos/images_angel_jpg\000006.jpg
# frame: 000007
# writing to file: ../data/videos/images_angel_jpg\000007.jpg
# frame: 000008
# writing to file: ../data/videos/images_angel_jpg\000008.jpg
# frame: 000009
# writing to file: ../data/videos/images_angel_jpg\000009.jpg
# frame: 000010
# writing to file: ../data/videos/images_angel_jpg\000010.jpg
# frame: 000011
# writing to file: ../data/videos/images_angel_jpg\000011.jpg
# frame: 000012
# writing to file: ../data/videos/images_angel_jpg\000012.jpg
# frame: 000013
# ...

# %%
import os
import multiprocessing as mp
import cv2

save_dir = "../data/videos"
video_dir = "../data/videos"
video_file = "../data/videos/angel_eyes3_big.wmv"

# Define absolute directory paths
ROOT_DIR = os.getcwd()
VIDEO_DIR = os.path.join(ROOT_DIR, video_dir)
VIDEO_SAVE_DIR = os.path.join(VIDEO_DIR, save_dir)
VIDEO_FILE_PATH = os.path.join(video_file)
print(VIDEO_FILE_PATH)

# Set up multiprocessing
num_processes = mp.cpu_count()
num_frames = cv2.VideoCapture(VIDEO_FILE_PATH).get(cv2.CAP_PROP_FRAME_COUNT)
frame_jump =  num_frames // num_processes
frame_width = cv2.VideoCapture(VIDEO_FILE_PATH).get(cv2.CAP_PROP_FRAME_WIDTH)
frame_height = cv2.VideoCapture(VIDEO_FILE_PATH).get(cv2.CAP_PROP_FRAME_HEIGHT)
print("cpus: {}, frames: {}, width: {}, height: {}".format(num_processes, num_frames, frame_width, frame_height))
# Out:
# ../data/videos/angel_eyes3_big.wmv
# cpus: 8, frames: 7026.0, width: 352.0, height: 240.0

# %%
import subprocess as sp
import os
os.getcwd()
# !conda activate OpenCV
sp.Popen(['python', '-m', 'print', 'Hello World!'], shell=True)#.stdout

# %%
import subprocess as sp
import os
import multiprocessing as mp
os.getcwd()

cpus = mp.cpu_count()

p = mp.Pool(cpus)

# ROOT_DIR = os.getcwd()
# MODEL_DIR = os.path.join(ROOT_DIR, "logs")
# VIDEO_DIR = os.path.join(ROOT_DIR, "videos")
# VIDEO_SAVE_DIR = os.path.join(VIDEO_DIR, "save")
# image_list = os.listdir(VIDEO_SAVE_DIR)
save_dir = "../data/videos/images_angel_jpg"
video_dir = "../data/videos"
video_file = "../data/videos/angel_eyes3_big.wmv"

# Define absolute directory paths
ROOT_DIR = os.getcwd()
VIDEO_DIR = os.path.join(video_dir)
VIDEO_SAVE_DIR = os.path.join(save_dir)
VIDEO_FILE_PATH = os.path.join(video_file)

def process_image(image_path):
    return sp.Popen(['python', '-m', 'sr.py', '--file', save_dir])    

def mp_test(image_list):
    return sp.Popen(['echo', 'Hello World!'], shell=True)

#p.map(process_image, image_list)
# for im in os.listdir(VIDEO_SAVE_DIR):
#     sp.Popen(['python', 'sr.py', '--file', os.path.join(VIDEO_SAVE_DIR, im)])
    #%run sr.py --file os.path.join(VIDEO_SAVE_DIR, im)


image_list = os.listdir(save_dir)
p.map(mp_test, image_list)

# %%
import subprocess as sp
import os
import multiprocessing as mp
import cv2
import numpy as np

# ROOT_DIR = os.getcwd()
# MODEL_DIR = os.path.join(ROOT_DIR, "logs")
# VIDEO_DIR = os.path.join(ROOT_DIR, "videos")
# VIDEO_SAVE_DIR = os.path.join(VIDEO_DIR, "save")
# image_list = os.listdir(VIDEO_SAVE_DIR)
save_dir = "images_8minanal"
video_dir = "videos"
video_file = "8minanal.mp4"

# Define absolute directory paths
ROOT_DIR = os.getcwd()
VIDEO_DIR = os.path.join(ROOT_DIR, video_dir)
VIDEO_SAVE_DIR = os.path.join(VIDEO_DIR, save_dir)
VIDEO_FILE_PATH = os.path.join(VIDEO_DIR, video_file)
video = cv2.VideoCapture(VIDEO_FILE_PATH)

# Find OpenCV version
(major_ver, minor_ver, subminor_ver) = (cv2.__version__).split('.')

if int(major_ver)  < 3 :
    fps = video.get(cv2.cv.CV_CAP_PROP_FPS)
    print("Frames per second using video.get(cv2.cv.CV_CAP_PROP_FPS): {0}".format(fps))
else :
    fps = video.get(cv2.CAP_PROP_FPS)
    print("Frames per second using video.get(cv2.CAP_PROP_FPS) : {0}".format(fps))

video.release()

# %%
def make_video(outvid, images=None, fps=30, size=None,
               is_color=True, format="FMP4"):
    """
    Create a video from a list of images.
 
    @param      outvid      output video
    @param      images      list of images to use in the video
    @param      fps         frame per second
    @param      size        size of each frame
    @param      is_color    color
    @param      format      see http://www.fourcc.org/codecs.php
    @return                 see http://opencv-python-tutroals.readthedocs.org/en/latest/py_tutorials/py_gui/py_video_display/py_video_display.html
 
    The function relies on http://opencv-python-tutroals.readthedocs.org/en/latest/.
    By default, the video will have the size of the first image.
    It will resize every image to this size before adding them to the video.
    """
    from cv2 import VideoWriter, VideoWriter_fourcc, imread, resize
    fourcc = VideoWriter_fourcc(*format)
    vid = None
    for image in images:
        if not os.path.exists(image):
            raise FileNotFoundError(image)
        img = imread(image)
        if vid is None:
            if size is None:
                size = img.shape[1], img.shape[0]
            vid = VideoWriter(outvid, fourcc, float(fps), size, is_color)
        if size[0] != img.shape[1] and size[1] != img.shape[0]:
            img = resize(img, size)
        vid.write(img)
    vid.release()
    return vid

import glob
import os

# Directory of images to run detection on
ROOT_DIR = os.getcwd()
VIDEO_DIR = os.path.join(ROOT_DIR, "videos")
VIDEO_SAVE_DIR = os.path.join(VIDEO_DIR, "images")
images = list(glob.iglob(os.path.join(VIDEO_SAVE_DIR, '*.*')))
# Sort the images by integer index
images = sorted(images, key=lambda x: float(os.path.split(x)[1][:-3]))

outvid = os.path.join(VIDEO_DIR, "ryan_srgan.mp4")
make_video(outvid, images, fps=fps)

# %%
import glob
import os
list(glob.iglob(os.path.join(VIDEO_SAVE_DIR, '*.*')))
